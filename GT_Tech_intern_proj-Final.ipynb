# %% [markdown]
# ## Topic Modeling - Natural Language Processing

# %%
import pandas as pd

# %%
import json
import csv
import zipfile,os

# %%
# Extracting documents contents of the zipped file in the given folder
def get_file(dir_path,tar_dir,ext):
    for item in os.listdir(data_dir):
        if item.endswith(extension): 
            file_name=os.path.join(data_dir,item)
            zip_ref=zipfile.ZipFile(file_name)
            zip_ref.extractall(tar_dir)
            zip_ref.close()

# %%
data_dir = r"D:\Machine Learning\Internship_GTechnology_Edu"
tar_dir=os.getcwd()
extension=".zip"

# %%
# To extract the file from the location provided and unzip the file for usage
get_file(data_dir,tar_dir,extension)

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Back_prop_code_MML.ipynb',
#  'corpusd_cleandata',
#  'csv_file.csv',
#  'GT_Tech_intern_proj-Copy1.ipynb',
#  'GT_Tech_intern_proj.ipynb',
#  'GT_Tech_NLP_Proj.ipynb',
#  'Neural_Model_from_Scratch_Word.ipynb',
#  'PreProcess.py',
#  'proc_text.csv',
#  'seeds_dataset.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  '__pycache__']

# %%
# Creating Data path
data_path=os.path.join(os.getcwd(),'corpusd_cleandata')

# %%
# Converting the document present in json form to csv

def json_2_csv(dir_path):
    data_list=os.listdir(dir_path)
    c=0
    csv_file=open("csv_file.csv",'w',encoding='utf-8')
    csv_writer=csv.writer(csv_file)
    for data_fl in data_list:
        with open(os.path.join(data_path,data_fl)) as json_file:
            data = json.load(json_file)
        if c==0:
            csv_writer.writerow(data.keys())
            csv_writer.writerow(data.values())
            c+=1
        else:
            csv_writer.writerow(data.values())
    csv_file.close()
    return (os.path.abspath("csv_file.csv"))

# %%
# Extracting data from json file in csv format
csv_file_path=json_2_csv(data_path)

# %%
# Reading the csv file and looking the first five rows.
import pandas as pd
df=pd.read_csv("csv_file.csv")
df.head()
# Out:
#                                      id result_metadata  \
# 0  004ca50f-893e-4484-9e4d-3324ec705edf    {'score': 1}
# 1  005bcee4-dad0-444b-ae5c-9fb28d59e174    {'score': 1}
# 2  00779d3d-a3eb-40d1-a12c-d7b9fa54f819    {'score': 1}
# 3  007b1dde-465d-4c85-86e4-842a1d8c601b    {'score': 1}
# 4  0090cb72-17a2-4a19-a646-8bade2f83e70    {'score': 1}
#
#                                            copyright  \
# 0  (c)  2020, TenderNews.com Provided by SyndiGat...
# 1              Copyright AS Eesti Meedia Jun 5, 2020
# 2  © Copyright 2020, Marietta Daily Journal. All ...
# 3       Copyright Franciscan Media, LLC Jun/Jul 2020
# 4  (c)  2000 - 2020 Al Bawaba. All Rights Reserve...
#
#                      geoOrigin        sourceType  \
# 0             New Delhi, India  General Newswire
# 1             Tallinn, Estonia  General Newswire
# 2            Marietta, Georgia         Newspaper
# 3             Cincinnati, Ohio          Magazine
# 4  Dubai, United Arab Emirates  General Newswire
#
# ...

# %%
## Extracting the text column and creating the dataframe for further operation
df_text=df.text.reset_index()
df_text.drop('index',axis=1,inplace=True)
df_text
# Out:
#                                                    text
# 0     fencing of riat market in kanyikela ward.\r\n\...
# 1     VILNIUS, Jun 05, BNS - Visitors from low-risk ...
# 2     Every year, Georgia yard sale shoppers spend t...
# 3     Adults have an opportunity to model good onlin...
# 4     Company : OFFICE OF XINHE SUB-DISTRICT OFFICE,...
# ...                                                 ...
# 1995  According to [Kmov.com](http://Kmov.com), an a...
# 1996  PELHAM  For parent Daniela DeLuca, the Farewe...
# 1997  Christine Blackburne The Associated Press\r\n\...
# 1998  Renewal of sports hall floor Viktoria elementa...
# 1999  CINCINNATI \- Hamilton County sheriff's deputi...
#
# [2000 rows x 1 columns]

# %%
# Visualizing the documents no 1
df_text.text[0]
# Out:
# 'fencing of riat market in kanyikela ward.\r\n\r\nmore info : Location : KENYA BidDate : 6/15/2020 Tender Country : KENYA Tender\r\nType : Tenders Tendering Authority : County Government Of Homa Bay Tendering\r\nAuthority Address : p.o box: 469-40300, homa-bay county, Financier : Self\r\nFunded'

# %% [markdown]
# ## Pre Processing & Cleaning of Documents

# %%
import PreProcess # Set of Methods for preprocessing and cleaning documents (PreProcess.py)

# %%
def pre_process_txt(string_txt):
    return(PreProcess.preprocess_text(string_txt))

# %%
# # Application of pre-processing on the text column to create the processed text
df_text['proc_text']=df_text['text'].apply(pre_process_txt)

# %%
df_text.head()
# Out:
#                                                 text  \
# 0  fencing of riat market in kanyikela ward.\r\n\...
# 1  VILNIUS, Jun 05, BNS - Visitors from low-risk ...
# 2  Every year, Georgia yard sale shoppers spend t...
# 3  Adults have an opportunity to model good onlin...
# 4  Company : OFFICE OF XINHE SUB-DISTRICT OFFICE,...
#
#                                            proc_text
# 0  fencing riat market kanyikela ward info locati...
# 1  vilnius jun bns visitor low risk country outsi...
# 2  every year georgia yard sale shopper spend fir...
# 3  adult opportunity model good online behavior y...
# 4  company office xinhe sub district office peopl...

# %%
#Processed token text
df_text['proc_text_tokn']=df_text.proc_text.apply(PreProcess.Tokenize)

# %%
# Visualizing the data frame
df_text.head()
# Out:
#                                                 text  \
# 0  fencing of riat market in kanyikela ward.\r\n\...
# 1  VILNIUS, Jun 05, BNS - Visitors from low-risk ...
# 2  Every year, Georgia yard sale shoppers spend t...
# 3  Adults have an opportunity to model good onlin...
# 4  Company : OFFICE OF XINHE SUB-DISTRICT OFFICE,...
#
#                                            proc_text  \
# 0  fencing riat market kanyikela ward info locati...
# 1  vilnius jun bns visitor low risk country outsi...
# 2  every year georgia yard sale shopper spend fir...
# 3  adult opportunity model good online behavior y...
# 4  company office xinhe sub district office peopl...
#
#                                       proc_text_tokn
# 0  [fencing, riat, market, kanyikela, ward, info,...
# 1  [vilnius, jun, bns, visitor, low, risk, countr...
# 2  [every, year, georgia, yard, sale, shopper, sp...
# 3  [adult, opportunity, model, good, online, beha...
# 4  [company, office, xinhe, sub, district, office...

# %%
df_text.to_csv("proc_text.csv")

# %%
df_text=pd.read_csv("proc_text.csv")

# %%
#Processed token text
df_text['proc_text_tokn']=df_text.proc_text.apply(PreProcess.Tokenize)

# %%
df_text.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0  fencing of riat market in kanyikela ward.\r\n\...
# 1           1  VILNIUS, Jun 05, BNS - Visitors from low-risk ...
# 2           2  Every year, Georgia yard sale shoppers spend t...
# 3           3  Adults have an opportunity to model good onlin...
# 4           4  Company : OFFICE OF XINHE SUB-DISTRICT OFFICE,...
#
#                                            proc_text  \
# 0  fencing riat market kanyikela ward info locati...
# 1  vilnius jun bns visitor low risk country outsi...
# 2  every year georgia yard sale shopper spend fir...
# 3  adult opportunity model good online behavior y...
# 4  company office xinhe sub district office peopl...
#
#                                       proc_text_tokn
# 0  [fencing, riat, market, kanyikela, ward, info,...
# 1  [vilnius, jun, bns, visitor, low, risk, countr...
# 2  [every, year, georgia, yard, sale, shopper, sp...
# ...

# %%
# Visualization of text and the processed text
df_text.text[1]
# Out:
# 'VILNIUS, Jun 05, BNS - Visitors from low-risk countries outside the European\r\nUnion should not be required to self-isolate after the bloc opens its external\r\nborders, Lithuanian Interior Minister Rita Tamasuniene said on Friday.\r\n\r\n"Once decisions to allow entry for third-country nationals have been made, it\r\nwould make sense not to apply quarantine requirements to arrivals from third\r\ncountries of low epidemiological risk," she said in a press release.\r\n\r\nTamasuniene discussed these ideas during an informal video conference of EU\r\ninterior ministers earlier on Friday.\r\n\r\nAccording to the Lithuanian minister, the European Commission and the European\r\nCenter for Disease Prevention and Control could regularly issue guidelines or\r\nrecommendations for a coordinated list of such non-EU countries.\r\n\r\n"We believe that all member states should consistently follow such\r\nrecommendations," she said.\r\n\r\nIn line with the Commission\'s recommendations, Lithuani
# ...

# %%
df_text.proc_text[1]
# Out:
# 'vilnius jun bns visitor low risk country outside european union required self isolate bloc open external border lithuanian interior minister rita tamasuniene said friday decision allow entry third country national made would make sense apply quarantine requirement arrival third country low epidemiological risk said press release tamasuniene discussed idea informal video conference interior minister earlier friday according lithuanian minister european commission european center disease prevention control could regularly issue guideline recommendation coordinated list non country believe member state consistently follow recommendation said line commission recommendation lithuania shut external border non essential travel non national ban expire june unless extended redakcija bns mailto redakcija bns vilnius newsroom'

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# Creating the document list as a reference to the dictionary
docs = df_text.proc_text_tokn.tolist()

# %% [markdown]
# ## Bag_of_Words representation of the corpus

# %%
from gensim.corpora import Dictionary
# Out:
# C:\Users\jbhsm\anaconda3\envs\NLP\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# Creating the dictionary and the corpus

def corp_dict(docs,filt_val,filt_extreme=False):
    """
    This function will take tokenized document list as input, initialize a dictionary with that and create a bag of words
    corpus.It is also filter the words basis value given in filt_val(no_below and no_above) when filter extreme is true.
    
    docs = list of tokenized documents, Ex. [fencing, riat, market, kanyikela, ward, info,..]
    filt_val = list of tuple, tuple containing (no_below,no_above) - ex. [(4,2),(4,0.5)].
                If the value passed is integer, words having repeatation below that particular value will be filtered out
                If given float, percentage availability of the word in the dictionary with respect to its frequency will be
                considered.
                filt_val will only be considered if filt_extreme is TRUE
    filt_extreme = bool, True or False   
    
    Return:
    list of tuples consisting of dictionary and corpus - Ex. [(dictionary,corpus)]
    
    dictionary - iterable dictionary of gensim class. to print the dictionary loop over dictionary.items() and print the content.
    
    corpus - bag of words corpus, list of tuples. length of corpus is length of the document list or no. of documents
             the tuple consists of word id and frequecy of the word in the respective document.
             [(0, 1), (1, 2), (2, 2), (3, 1), (4, 1), (5, 1), (6, 2), (7, 1), (8, 1), (9, 1), (10, 1), (11, 1), (12, 2), (13, 1), 
             (14, 1),(15, 1), (16, 1), (17, 3), (18, 2), (19, 1), (20, 1)]
             
    
    """
    
    # Initializing Dictionary class instance with the document in discussion# Bag-of-words representation of the documents.
    lst=[]
     
    if filt_extreme:
        c=0
        for tupl in filt_val:
            c+=1
            dictionary = Dictionary(docs)
            dictionary.filter_extremes(no_below=tupl[0], no_above=tupl[1])
            dictionary.compactify()
            corpus_bow = [dictionary.doc2bow(doc) for doc in docs]
            lst.append((dictionary,corpus_bow))
            print("For Filter value set  {}".format(c))
            print('Number of unique tokens: %d' % len(dictionary))
            print('Number of documents: %d' % len(corpus_bow),'\n')
    else:
        dictionary = Dictionary(docs)
        corpus_bow = [dictionary.doc2bow(doc) for doc in docs]
        lst.append((dictionary,corpus_bow))
        
        print('Number of unique tokens: %d' % len(dictionary))
        print('Number of documents: %d' % len(corpus_bow),'\n')
    
    return lst

# %%
corp_dict_lst=corp_dict(docs,[(4,0.5),(2,0.2),(1,0.2)],True)
# Out:
# 2021-09-23 14:37:34,221 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2021-09-23 14:37:34,649 : INFO : built Dictionary(41677 unique tokens: ['address', 'authority', 'bay', 'biddate', 'box']...) from 2000 documents (total 563374 corpus positions)
# 2021-09-23 14:37:34,649 : INFO : Dictionary lifecycle event {'msg': "built Dictionary(41677 unique tokens: ['address', 'authority', 'bay', 'biddate', 'box']...) from 2000 documents (total 563374 corpus positions)", 'datetime': '2021-09-23T14:37:34.649058', 'gensim': '4.0.1', 'python': '3.6.12 |Anaconda, Inc.| (default, Sep  9 2020, 00:29:25) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'created'}
# 2021-09-23 14:37:34,691 : INFO : discarding 31871 tokens: [('homa', 2), ('kanyikela', 1), ('riat', 1), ('tamasuniene', 1), ('acworth', 1), ('adairsville', 1), ('calhoun', 3), ('cartersville', 1), ('cassville', 1), ('daylight', 3)]...
# ...

# %% [markdown]
# ## Creation of the Tfidf Model

# %%
from gensim.models import TfidfModel

# %%
def tfidf_vec(corpus):
    model = TfidfModel(corpus)  # fit mode
    vector_tfidf = model[corpus]
    return vector_tfidf

# %% [markdown]
# ## Latent Dirichlet Allocation using Bag of Words

# %%
from gensim.models import LdaModel

# %%
def lda_app(corpus_lst,topic_lst,passes,chunksize,iterations,eval_every=None):
    ''' 
    This function is a wrapper function and providing data to LdaModel function
    
    corpus_lst - list of tuples consisting of dictionary and bag of words corpus. Ex.[(dictionary,corpus_bow),
    (dictionary,corpus_bow),...]
    
    topic_lst - list of int – The number of requested latent topics to be extracted from the training corpus. For each integer, 
    which is the no.of topics, all the corpus available in the corpus list are run.

    passes (int) – Number of passes through the corpus during training. (may arneg between 10-50 ro more than that.)
    
    chunksize (int) – Number of documents to be used in each training chunk. (Batch size for processing)
    
    iterations (int) – Maximum number of iterations through the corpus when inferring the topic
    distribution of a corpus.
    
    
    eval_every (int, optional) – Log perplexity is estimated every that many updates. 
    Setting this to one slows down training by ~2x
    
    Returns 
    
    lst_corpus list contaning 
        model name - model_(Serial No = no. of corpus provided in the corpus list)_top_(no.of topic taken for modeling 
        as per list provided). Ex. model_3_top_10 
        model - the lda model
        corpus - Initial corpus provided
        dictionary - initially provided
        
        Such a list is created, since it is helpful for executing pyLDAviz
    '''
    
    
    c=1
    lst_corpus=[]
    for dict_corp_tup in corpus_lst:
        lst=[]
        for topic_sz in topic_lst:
            corpus=tfidf_vec(dict_corp_tup[1])
            model_name='model'+'_'+str(c)+'_'+'top'+'_'+str(topic_sz)
            model= LdaModel(corpus=corpus, num_topics=topic_sz,id2word=dict_corp_tup[0],passes=passes,
                                                                 iterations=iterations,chunksize=chunksize,
                                                                 eval_every=eval_every)
            
            lst.append(('model'+'_'+str(c)+'_'+'top'+'_'+str(topic_sz),model,dict_corp_tup[1],dict_corp_tup[0]))
        c+=1
        lst_corpus.append(lst)
    return lst_corpus

# %%
# Set training parameters.
num_topics = [3,6,10]
chunksize = 500
passes = 30
iterations = 400
eval_every = 2

# %%
model_lst= lda_app(corp_dict_lst,num_topics,passes,chunksize,iterations,eval_every)
# Out:
# 2021-09-23 14:38:10,640 : INFO : collecting document frequencies
# 2021-09-23 14:38:10,640 : INFO : PROGRESS: processing document #0
# 2021-09-23 14:38:10,712 : INFO : TfidfModel lifecycle event {'msg': 'calculated IDF weights for 2000 documents and 9806 features (263869 matrix non-zeros)', 'datetime': '2021-09-23T14:38:10.712988', 'gensim': '4.0.1', 'python': '3.6.12 |Anaconda, Inc.| (default, Sep  9 2020, 00:29:25) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'initialize'}
# 2021-09-23 14:38:10,712 : INFO : using symmetric alpha at 0.3333333333333333
# 2021-09-23 14:38:10,712 : INFO : using symmetric eta at 0.3333333333333333
# 2021-09-23 14:38:10,712 : INFO : using serial LDA version on this node
# ...

# %%
def topic_print(model,no_of_words):
    topics = model.print_topics(num_words=no_of_words)
    for topic in topics:
        print(topic)

# %%
corpus=model_lst[0]
no_of_words=6
for mod_nam,model,corp,diction in corpus:
    print("\n Model Name: ",mod_nam,'\n')
    topic_print(model,no_of_words)
# Out:
# 2021-09-23 19:20:05,773 : INFO : topic #0 (0.333): 0.016*"tender" + 0.012*"tendering" + 0.011*"authority" + 0.009*"germany" + 0.006*"financier" + 0.006*"info"
# 2021-09-23 19:20:05,775 : INFO : topic #1 (0.333): 0.002*"bse" + 0.002*"india" + 0.001*"contentservices" + 0.001*"fintech" + 0.001*"accord" + 0.001*"content"
# 2021-09-23 19:20:05,776 : INFO : topic #2 (0.333): 0.002*"said" + 0.002*"police" + 0.002*"news" + 0.001*"research" + 0.001*"document" + 0.001*"county"
# 2021-09-23 19:20:05,777 : INFO : topic #0 (0.167): 0.003*"wherein" + 0.002*"patent" + 0.001*"apparatus" + 0.001*"configured" + 0.001*"brandenburg" + 0.001*"plurality"
# 2021-09-23 19:20:05,778 : INFO : topic #1 (0.167): 0.010*"research" + 0.007*"news" + 0.004*"newsrx" + 0.004*"obtained" + 0.004*"journal" + 0.003*"doi"
# 2021-09-23 19:20:05,779 : INFO : topic #2 (0.167): 0.007*"tender" + 0.005*"tendering" + 0.004*"authority" + 0.004*"germany" + 0.002*"info" + 0.002*"financier"
# ...

# %%
corpus=model_lst[1]
no_of_words=6
for mod_nam,model,corp,diction in corpus:
    print("\n Model Name: ",mod_nam,'\n')
    topic_print(model,no_of_words)
# Out:
# 2021-09-23 19:19:51,070 : INFO : topic #0 (0.333): 0.009*"tender" + 0.007*"tendering" + 0.006*"authority" + 0.005*"germany" + 0.004*"info" + 0.004*"financier"
# 2021-09-23 19:19:51,071 : INFO : topic #1 (0.333): 0.001*"police" + 0.001*"document" + 0.001*"county" + 0.001*"research" + 0.001*"company" + 0.001*"case"
# 2021-09-23 19:19:51,071 : INFO : topic #2 (0.333): 0.003*"que" + 0.001*"la" + 0.001*"los" + 0.001*"por" + 0.001*"con" + 0.001*"del"
# 2021-09-23 19:19:51,072 : INFO : topic #0 (0.167): 0.015*"tender" + 0.013*"tendering" + 0.011*"authority" + 0.009*"germany" + 0.006*"info" + 0.006*"financier"
# 2021-09-23 19:19:51,073 : INFO : topic #1 (0.167): 0.002*"police" + 0.001*"county" + 0.001*"research" + 0.001*"case" + 0.001*"health" + 0.001*"city"
# 2021-09-23 19:19:51,074 : INFO : topic #2 (0.167): 0.005*"document" + 0.004*"krw" + 0.004*"international" + 0.004*"bid" + 0.003*"vietnam" + 0.003*"tender_no"
# ...

# %%
corpus=model_lst[2]
no_of_words=6
for mod_nam,model,corp,diction in corpus:
    print("\n Model Name: ",mod_nam,'\n')
    topic_print(model,no_of_words)
# Out:
# 2021-09-23 14:54:30,944 : INFO : topic #0 (0.333): 0.001*"police" + 0.001*"county" + 0.001*"research" + 0.001*"case" + 0.001*"health" + 0.001*"document"
# 2021-09-23 14:54:30,952 : INFO : topic #1 (0.333): 0.000*"deleted" + 0.000*"koppes" + 0.000*"cartoon" + 0.000*"ohman" + 0.000*"editorial" + 0.000*"kreations"
# 2021-09-23 14:54:30,952 : INFO : topic #2 (0.333): 0.003*"tender" + 0.002*"tendering" + 0.002*"authority" + 0.002*"germany" + 0.001*"financier" + 0.001*"info"
# 2021-09-23 14:54:30,952 : INFO : topic #0 (0.167): 0.006*"tender" + 0.005*"tendering" + 0.004*"authority" + 0.003*"germany" + 0.002*"financier" + 0.002*"info"
# 2021-09-23 14:54:30,952 : INFO : topic #1 (0.167): 0.001*"police" + 0.001*"county" + 0.001*"research" + 0.001*"case" + 0.001*"health" + 0.001*"city"
# 2021-09-23 14:54:30,952 : INFO : topic #2 (0.167): 0.001*"bse" + 0.001*"india" + 0.000*"fintech" + 0.000*"accord" + 0.000*"nav" + 0.000*"contentservices"
# ...

# %%
corpus=model_lst[2]
no_of_words=6
for mod_nam,model,corp,diction in corpus:
    for index,score in sorted(model[corp[0]], key=lambda tup: -1*tup[1]):
    
    
        print("\nScore: {}\t \nTopic: {}".format(score, model.print_topic(index, no_of_words)))
# Out:
# Score: 0.7550726532936096
# Topic: 0.003*"tender" + 0.002*"tendering" + 0.002*"authority" + 0.002*"germany" + 0.001*"financier" + 0.001*"info"
#
# Score: 0.23330238461494446
# Topic: 0.001*"police" + 0.001*"county" + 0.001*"research" + 0.001*"case" + 0.001*"health" + 0.001*"document"
#
# Score: 0.011624947190284729
# Topic: 0.000*"deleted" + 0.000*"koppes" + 0.000*"cartoon" + 0.000*"ohman" + 0.000*"editorial" + 0.000*"kreations"
#
# Score: 0.6790269613265991
# Topic: 0.006*"tender" + 0.005*"tendering" + 0.004*"authority" + 0.003*"germany" + 0.002*"financier" + 0.002*"info"
#
# Score: 0.29789701104164124
# Topic: 0.001*"police" + 0.001*"county" + 0.001*"research" + 0.001*"case" + 0.001*"health" + 0.001*"city"
#
# Score: 0.5255728363990784
# Topic: 0.002*"police" + 0.002*"county" + 0.001*"case" + 0.001*"city" + 0.001*"health" + 0.001*"school"
#
# Score: 0.4448501467704773
# ...

# %%
import pyLDAvis.gensim

# %% [markdown]
# ### Model -1

# %%
# Model 1 - with 3 topics
lda_model=model_lst[0][0][1]
corpus_bow=model_lst[0][0][2]
dictionary=model_lst[0][0][3]

# %%
lda_display = pyLDAvis.gensim.prepare(lda_model, corpus_bow, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# 2021-09-23 19:11:44,948 : INFO : NumExpr defaulting to 8 threads.
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.2.2/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el99843039871220136912312871"></div>
# <script type="text/javascript">
#
# ...

# %%
# Model 1 with 6 topics
lda_model=model_lst[0][1][1]
corpus_bow=model_lst[0][1][2]
dictionary=model_lst[0][1][3]

# %%
lda_display = pyLDAvis.gensim.prepare(lda_model, corpus_bow, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.2.2/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el998430398712212161589919716"></div>
# <script type="text/javascript">
#
# ...

# %%
# Model 1 with 10 topics

lda_model=model_lst[0][2][1]
corpus_bow=model_lst[0][2][2]
dictionary=model_lst[0][2][3]

# %%
lda_display = pyLDAvis.gensim.prepare(lda_model, corpus_bow, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.2.2/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el9984303987240557691946223"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# ## Discussions

# %% [markdown]
#     1. 1st Corpus which is trimmed to -  no_below=4, no_above=0.2 - gives better seggregation of topics
#     2. As we include more vocabularies, topics seen to overlap more.

# %% [markdown]
#     1. Word Embedding
#         https://towardsdatascience.com/3-silver-bullets-of-word-embedding-in-nlp-10fa8f50cc5a
#     2. lda2vec
#         https://towardsdatascience.com/combing-lda-and-word-embeddings-for-topic-modeling-fe4a1315a5b4
#     3. contextual embedding
#         https://towardsdatascience.com/contextual-embeddings-for-nlp-sequence-labeling-9a92ba5a6cf0
#     4. Hybrid lda2vec Algo - Chris Moody
#         https://multithreaded.stitchfix.com/blog/2016/05/27/lda2vec/#topic=38&lambda=1&term=
#         https://towardsdatascience.com/replacing-your-word-embeddings-by-contextualized-word-vectors-9508877ad65d
#         https://github.com/cemoody/lda2vec
#     5.  Edu_Assign_3_Seq_Learn_1.ipynb
